# %%
import numpy as np
import pandas as pd
from sklearn import datasets
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
boston = pd.read_csv('housingdata.csv')
boston
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93   0.0  0.573  6.030   NaN  2.5050    1  273
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# ...

# %%
boston.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  486.000000  486.000000  486.000000  486.000000  506.000000  506.000000
# mean     3.611874   11.211934   11.083992    0.069959    0.554695    6.284634
# std      8.720192   23.388876    6.835896    0.255340    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.081900    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.253715    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.560263   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  486.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.518519    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
print(type(boston))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
boston.isnull().sum()
# Out:
# CRIM       20
# ZN         20
# INDUS      20
# CHAS       20
# NOX         0
# RM          0
# AGE        20
# DIS         0
# RAD         0
# TAX         0
# PTRATIO     0
# B           0
# LSTAT      20
# MEDV        0
# dtype: int64

# %%
boston['CRIM'] = boston['CRIM'].fillna(boston['CRIM'].mean())
boston['ZN'] = boston['ZN'].fillna(boston['ZN'].mean())
boston['INDUS'] = boston['INDUS'].fillna(boston['INDUS'].mean())
boston['CHAS'] = boston['CHAS'].fillna(boston['CHAS'].mode()[0])
boston['AGE'] = boston['AGE'].fillna(boston['AGE'].mean())
boston['LSTAT'] = boston['LSTAT'].fillna(boston['LSTAT'].mean())

# %%
print(boston.keys())
# Out:
# Index(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX',
#        'PTRATIO', 'B', 'LSTAT', 'MEDV'],
#       dtype='object')

# %%
boston.shape
# Out:
# (506, 14)

# %%
reg=LinearRegression()

# %%
X_train, X_test, Y_train, Y_test = train_test_split(boston, boston['MEDV'], test_size = 0.20,random_state=10)
print(X_train.shape)
print(X_test.shape)
print(Y_train.shape)
print(Y_test.shape)
# Out:
# (404, 14)
# (102, 14)
# (404,)
# (102,)

# %%
reg.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
y_pred=reg.predict(X_test)

# %%
print(y_pred)
# Out:
# [28.4 31.1 23.5 26.6 19.6 14.3 50.  14.3 20.7 37.6 20.4 27.5 36.2 32.
#  33.1 48.8 24.6 26.4 23.2 17.  41.3 14.9 18.5 25.  36.4 19.5 27.1 14.9
#  46.  17.9 30.3 31.6 23.1 24.7 16.7 18.3  8.4 37.3 22.1 22.  46.7 30.1
#  12.1 29.1 16.6 23.9 19.9 21.4 45.4 15.6 22.7 12.5 24.3 43.8 22.  33.8
#  19.3 22.6 16.1 15.  19.6 21.2 50.  50.  29.4 17.8 22.8  8.8 32.5 42.8
#  12.6 28.6 19.1 50.  27.5 23.7 50.   7.2 18.7 37.  22.9 22.9 17.1 22.
#  23.6 23.9 27.1 29.  22.2  7.  20.7 18.5 21.6 23.  16.  15.  23.9 24.4
#  22.6 19.8 22.2 18.6]

# %%
print(Y_test)
# Out:
# 305    28.4
# 193    31.1
# 65     23.5
# 349    26.6
# 151    19.6
#        ...
# 208    24.4
# 174    22.6
# 108    19.8
# 242    22.2
# 102    18.6
# Name: MEDV, Length: 102, dtype: float64

# %%
reg.score(X_test,Y_test)
# Out:
# 1.0

# %%
from sklearn.metrics import mean_squared_error
y_pred = reg.predict(X_test)
rmse = (np.sqrt(mean_squared_error(Y_test, y)))
r2 = round(reg.score(X_test, Y_test),2)
print("The model performance for training set")
print(" ")
print("Root Mean Squared Error: {}".format(rmse))
print("R^2: {}".format(r2))
print("\n")
# Out:
# The model performance for training set
#
# Root Mean Squared Error: 1.3551464067663889e-14
# R^2: 1.0

# %%
adult = pd.read_csv('adult.csv')

# %%
adult
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 0       25       Private  226802          11th                7
# 1       38       Private   89814       HS-grad                9
# 2       28     Local-gov  336951    Assoc-acdm               12
# 3       44       Private  160323  Some-college               10
# 4       18             ?  103497  Some-college               10
# ...    ...           ...     ...           ...              ...
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital-status         occupation relationship   race  gender  \
# 0           Never-married  Machine-op-inspct    Own-child  Black    Male
# ...

# %%
adult.describe()
# Out:
#                 age        fnlwgt  educational-num  capital-gain  \
# count  48842.000000  4.884200e+04     48842.000000  48842.000000
# mean      38.643585  1.896641e+05        10.078089   1079.067626
# std       13.710510  1.056040e+05         2.570973   7452.019058
# min       17.000000  1.228500e+04         1.000000      0.000000
# 25%       28.000000  1.175505e+05         9.000000      0.000000
# 50%       37.000000  1.781445e+05        10.000000      0.000000
# 75%       48.000000  2.376420e+05        12.000000      0.000000
# max       90.000000  1.490400e+06        16.000000  99999.000000
#
#        capital-loss  hours-per-week
# count  48842.000000    48842.000000
# mean      87.502314       40.422382
# std      403.004552       12.391444
# min        0.000000        1.000000
# 25%        0.000000       40.000000
# 50%        0.000000       40.000000
# 75%        0.000000       45.000000
# max     4356.000000       99.000000

# %%
# Step 2: Group by a categorical column (e.g. 'education'), summarize a numeric column (e.g. 'hours-per-week')
summary = adult.groupby('education')['hours-per-week'].agg(
    Mean='mean',
    Median='median',
    Min='min',
    Max='max',
    Std_Dev='std'
)

print(summary)
# Out:
#                    Mean  Median  Min  Max    Std_Dev
# education
# 10th          36.986321    40.0    1   99  13.918007
# 11th          33.952539    40.0    1   99  13.996803
# 12th          35.374429    40.0    4   99  12.620268
# 1st-4th       38.761134    40.0    4   96  12.226671
# 5th-6th       38.923379    40.0    3   99  11.372194
# 7th-8th       39.003141    40.0    2   99  14.562775
# 9th           38.359788    40.0    1   99  11.464783
# Assoc-acdm    40.809494    40.0    1   99  12.199101
# Assoc-voc     41.658418    40.0    1   99  10.943312
# Bachelors     42.482492    40.0    1   99  11.423058
# Doctorate     46.582492    45.0    1   99  14.919597
# HS-grad       40.640775    40.0    1   99  11.423842
# Masters       43.575837    40.0    1   99  12.140942
# Preschool     36.566265    40.0   10   75  11.434002
# Prof-school   47.579137    48.0    2   99  14.983435
# Some-college  38.865784    40.0    1   99  12.796180

# %%
mean_hours_list = summary['Mean'].tolist()
print(mean_hours_list)
# Out:
# [36.98632109431246, 33.95253863134658, 35.37442922374429, 38.76113360323887, 38.923379174852656, 39.003141361256546, 38.35978835978836, 40.80949406620862, 41.658418243571084, 42.48249221183801, 46.582491582491585, 40.6407754688292, 43.575837410613474, 36.566265060240966, 47.57913669064748, 38.86578415149844]
